# %% [markdown]
# # Analysis 1
#
# First program to predict the GDP growth.
#
# We load the data from a sqlite3 data set and predicted the GDP growth value with a Linear Regression model.
#
# We didn't understand the problem, so this model predicted the GDP growth for the same year

# %%
import sys
sys.path.append("..") #To import from the utils package

import utils
from utils import config

import pandas as pd
import sqlite3
import numpy as np

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
#Load data from the dataset

conn = sqlite3.connect('../db.sqlite3')

indicators = config.INDICATORS
separator = "',\n'"
sql_string = f""" SELECT
                t2.Country,
                t1.Year,
                t3.IndicatorName,
                t1.Value                
                FROM CountryIndicators t1
                LEFT JOIN
                (SELECT ShortName as Country, CountryCode from Countries) t2
                ON t1.CountryCode = t2.CountryCode
                LEFT JOIN
                (SELECT IndicatorCode, IndicatorName from Indicators)t3
                ON t1.IndicatorCode = t3.IndicatorCode
                WHERE t3.IndicatorName in ('{"','".join(indicators)}');"""

df = pd.read_sql(sql_string,conn)
df = df.groupby(["Country","Year","IndicatorName"]).sum().squeeze().unstack()
df = df.reset_index(level=["Country","Year"])


# Rows where our target is not missing
target = config.TARGET
df = df[df[target].notna()]
df = df.dropna(axis='columns',thresh=6000)
df = df.dropna()
df
# Out:
# IndicatorName      Country  Year  Agriculture, value added (% of GDP)  \
# 43             Afghanistan  2003                            37.765444
# 44             Afghanistan  2004                            30.271674
# 45             Afghanistan  2005                            31.750991
# 46             Afghanistan  2006                            29.249737
# 47             Afghanistan  2007                            30.622854
# ...                    ...   ...                                  ...
# 12019             Zimbabwe  2006                            20.281820
# 12020             Zimbabwe  2007                            21.597907
# 12021             Zimbabwe  2008                            19.398886
# 12022             Zimbabwe  2009                            15.071770
# 12023             Zimbabwe  2010                            14.541420
#
# IndicatorName  CO2 emissions (kg per 2005 US$ of GDP)  Coal rents (% of GDP)  \
# 43                                           0.185800               0.004666
# 44                                           0.169567               0.018587
# 45                                           0.213297               0.010937
# 46                                           0.250239               0.011345
# 47                                           0.302756               0.083463
# ...                                               ...                    ...
# 12019                                        1.844721               1.059730
# 12020                                        1.818080               1.790678
# 12021                                        1.743141               4.968032
# 12022                                        1.764045               0.959147
# 12023                                        1.735414               1.637218
#
# IndicatorName  Discrepancy in expenditure estimate of GDP (current LCU)  \
# 43                                                  0.000000e+00
# 44                                                  0.000000e+00
# 45                                                  1.000000e+02
# 46                                                 -1.950000e+05
# 47                                                 -5.033000e+05
# ...                                                          ...
# 12019                                               2.750000e-07
# 12020                                               1.000000e+02
# 12021                                               1.670000e-06
# 12022                                               7.519306e+00
# 12023                                               6.486081e+00
#
# IndicatorName  Exports of goods and services (% of GDP)  \
# 43                                            43.556869
# 44                                            33.996494
# 45                                            27.395256
# 46                                            26.470293
# 47                                            17.823714
# ...                                                 ...
# 12019                                         35.956169
# 12020                                         37.785373
# 12021                                         41.466849
# 12022                                         22.013601
# 12023                                         36.780771
#
# IndicatorName  External balance on goods and services (% of GDP)  \
# 43                                                    -50.787301
# 44                                                    -53.142830
# 45                                                    -50.071889
# 46                                                    -47.614764
# 47                                                    -40.526333
# ...                                                          ...
# 12019                                                 -10.908312
# 12020                                                  -8.602158
# 12021                                                 -26.587940
# 12022                                                 -24.451602
# 12023                                                 -26.808845
#
# IndicatorName  Final consumption expenditure, etc. (% of GDP)  \
# 43                                                 133.941635
# 44                                                 134.350525
# 45                                                 128.503680
# 46                                                 124.258530
# 47                                                 120.661392
# ...                                                       ...
# 12019                                              109.337150
# 12020                                              101.492404
# 12021                                              121.460033
# 12022                                              109.347179
# 12023                                              102.829081
#
# IndicatorName  Foreign direct investment, net inflows (% of GDP)  ...  \
# 43                                                      1.261004  ...
# 44                                                      3.536115  ...
# 45                                                      4.318673  ...
# 46                                                      3.372252  ...
# 47                                                      1.916833  ...
# ...                                                          ...  ...
# 12019                                                   0.734768  ...
# 12020                                                   1.301978  ...
# 12021                                                   1.168557  ...
# 12022                                                   1.287226  ...
# 12023                                                   1.760743  ...
#
# IndicatorName  Manufacturing, value added (% of GDP)  \
# 43                                         17.080612
# 44                                         17.879127
# 45                                         16.937529
# 46                                         16.736761
# 47                                         18.052621
# ...                                              ...
# 12019                                      16.888957
# 12020                                      16.401347
# 12021                                      16.658966
# 12022                                      15.475782
# 12023                                      13.933501
#
# IndicatorName  Merchandise trade (% of GDP)  Mineral rents (% of GDP)  \
# 43                                48.978446                  0.000000
# 44                                46.958998                  0.000000
# 45                                45.493313                  0.000000
# 46                                44.777130                  0.000000
# 47                                35.311414                  0.000000
# ...                                     ...                       ...
# 12019                             78.987541                  5.050407
# 12020                             93.538297                  6.849553
# 12021                            116.629226                  3.828349
# 12022                             63.367034                  1.842701
# 12023                             74.284772                  3.918298
#
# IndicatorName  Natural gas rents (% of GDP)  Oil rents (% of GDP)  \
# 43                                 0.056478                   0.0
# 44                                 0.053260                   0.0
# 45                                 0.071615                   0.0
# 46                                 0.061334                   0.0
# 47                                 0.087198                   0.0
# ...                                     ...                   ...
# 12019                              0.000000                   0.0
# 12020                              0.000000                   0.0
# 12021                              0.000000                   0.0
# 12022                              0.000000                   0.0
# 12023                              0.000000                   0.0
#
# IndicatorName  Population ages 15-64 (% of total)  \
# 43                                      49.679527
# 44                                      49.938187
# 45                                      50.231455
# 46                                      50.106659
# 47                                      49.999907
# ...                                           ...
# 12019                                   55.035123
# 12020                                   55.165667
# 12021                                   55.241288
# 12022                                   55.268476
# 12023                                   55.252983
#
# IndicatorName  Population ages 65 and above (% of total)  \
# 43                                              2.188803
# 44                                              2.180380
# 45                                              2.176046
# 46                                              2.197008
# 47                                              2.213286
# ...                                                  ...
# 12019                                           3.262210
# 12020                                           3.271113
# 12021                                           3.270351
# 12022                                           3.251746
# 12023                                           3.211889
#
# IndicatorName  Services, etc., value added (% of GDP)  \
# 43                                          39.313349
# 44                                          43.015785
# 45                                          40.888792
# 46                                          41.934798
# 47                                          42.032443
# ...                                               ...
# 12019                                       47.391100
# 12020                                       45.327139
# 12021                                       49.512676
# 12022                                       55.284308
# 12023                                       54.643285
#
# IndicatorName  Total natural resources rents (% of GDP)  Trade (% of GDP)
# 43                                             3.342334        137.901039
# 44                                             2.008389        121.135819
# 45                                             1.744103        104.862401
# 46                                             2.328506        100.555349
# 47                                             1.948909         76.173761
# ...                                                 ...               ...
# 12019                                         11.707665         82.820649
# 12020                                         17.477170         84.172904
# 12021                                         23.375405        109.521637
# 12022                                          9.257156         68.478805
# 12023                                         11.380309        100.370387
#
# [3708 rows x 41 columns]

# %%
#Filter one contry on the data set
country_list = df.Country.unique() #Array with all column names
country = df.loc[df["Country"] == "United Kingdom"]
country.head()
# Out:
# IndicatorName         Country  Year  Agriculture, value added (% of GDP)  \
# 11370          United Kingdom  1990                             1.477654
# 11371          United Kingdom  1991                             1.457517
# 11372          United Kingdom  1992                             1.437402
# 11373          United Kingdom  1993                             1.445419
# 11374          United Kingdom  1994                             1.485601
#
# IndicatorName  CO2 emissions (kg per 2005 US$ of GDP)  Coal rents (% of GDP)  \
# 11370                                        0.343654                    0.0
# 11371                                        0.354780                    0.0
# 11372                                        0.346588                    0.0
# 11373                                        0.331202                    0.0
# 11374                                        0.318997                    0.0
#
# IndicatorName  Discrepancy in expenditure estimate of GDP (current LCU)  \
# 11370                                               1.298827e+10
# 11371                                               1.608825e+10
# 11372                                               1.422163e+10
# 11373                                               1.449901e+10
# 11374                                               8.441358e+09
#
# IndicatorName  Exports of goods and services (% of GDP)  \
# 11370                                         22.566717
# 11371                                         21.856641
# 11372                                         22.173889
# 11373                                         24.019885
# 11374                                         25.225082
#
# IndicatorName  External balance on goods and services (% of GDP)  \
# 11370                                                  -1.758669
# 11371                                                  -0.321173
# 11372                                                  -0.650429
# 11373                                                  -0.301669
# 11374                                                   0.032850
#
# IndicatorName  Final consumption expenditure, etc. (% of GDP)  \
# 11370                                               79.726885
# 11371                                               81.526772
# 11372                                               82.585038
# 11373                                               82.673005
# 11374                                               81.378698
#
# IndicatorName  Foreign direct investment, net inflows (% of GDP)  ...  \
# 11370                                                   3.064820  ...
# 11371                                                   1.439579  ...
# 11372                                                   1.403704  ...
# 11373                                                   1.556281  ...
# 11374                                                   0.940394  ...
#
# IndicatorName  Manufacturing, value added (% of GDP)  \
# 11370                                      18.851817
# 11371                                      18.495990
# 11372                                      18.145697
# 11373                                      17.675679
# 11374                                      18.382617
#
# IndicatorName  Merchandise trade (% of GDP)  Mineral rents (% of GDP)  \
# 11370                             37.336300                  0.000349
# 11371                             34.556526                  0.000018
# 11372                             34.887524                  0.000000
# 11373                             36.810171                  0.000000
# 11374                             38.505826                  0.000000
#
# IndicatorName  Natural gas rents (% of GDP)  Oil rents (% of GDP)  \
# 11370                              0.239130              1.104960
# 11371                              0.265573              0.841082
# 11372                              0.221582              0.803568
# 11373                              0.352261              0.816852
# 11374                              0.307653              0.899358
#
# IndicatorName  Population ages 15-64 (% of total)  \
# 11370                                   65.297024
# 11371                                   65.148551
# 11372                                   64.990941
# 11373                                   64.840293
# 11374                                   64.728284
#
# IndicatorName  Population ages 65 and above (% of total)  \
# 11370                                          15.731817
# 11371                                          15.825512
# 11372                                          15.872651
# 11373                                          15.883870
# 11374                                          15.874763
#
# IndicatorName  Services, etc., value added (% of GDP)  \
# 11370                                       66.927854
# 11371                                       67.609531
# 11372                                       68.274433
# 11373                                       69.036803
# 11374                                       68.584535
#
# IndicatorName  Total natural resources rents (% of GDP)  Trade (% of GDP)
# 11370                                          1.372182         46.892102
# 11371                                          1.128163         44.034454
# 11372                                          1.045208         44.998207
# 11373                                          1.195468         48.341439
# 11374                                          1.233173         50.417315
#
# [5 rows x 41 columns]

# %%
#dataset = country #Info for one contry
dataset = df #Info for all contries

""" We first split the training and test
    make a copy of the test data in order to display de Country and Year
    and then drop these fields
    We are not taking into account the temporal nature of the data
"""
# X = dataset[features]
X = dataset.drop(columns=target)
y = dataset[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

X_train = X_train.drop(columns=["Country","Year"])
X_test2 = X_test
X_test = X_test.drop(columns=["Country","Year"])

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
print(type(X))
print(type(y))
# Out:
# X_train shape: (2595, 38)
# X_test shape: (1113, 38)
# y_train shape: (2595,)
# y_test shape: (1113,)
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
features = df.columns.tolist()
features.remove(target)
features.remove("Country")
features.remove("Year")

linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
linear_y_pred = linear_model.predict(X_test)

results_df = X_test2
results_df = results_df.drop(columns=features)
results_df["y_real"] = y_test
results_df["y_pred"] = linear_y_pred
results_df["err"] = np.absolute(results_df["y_real"] - results_df["y_pred"])
results_df["%_err"] = ((results_df["err"]) /(np.absolute (results_df["y_real"]))* 100)

print(f"RMSE: {mean_squared_error(y_test, linear_y_pred)**0.5}")
print(f"R^2: {r2_score(y_test, linear_y_pred)}")

results_df
# Out:
# RMSE: 1.1631006829665653
# R^2: 0.9426318898621734
# IndicatorName    Country  Year     y_real     y_pred       err       %_err
# 7080              Mexico  1999   2.667013   2.705370  0.038357    1.438184
# 8369            Pakistan  1972   0.813406   0.655465  0.157941   19.417236
# 8145              Norway  2003   0.919842   2.663716  1.743874  189.584067
# 446              Armenia  2005  13.865711  14.073340  0.207628    1.497423
# 395            Argentina  2005   9.198489   8.729284  0.469205    5.100890
# ...                  ...   ...        ...        ...       ...         ...
# 11684          Venezuela  1998   0.294055   1.118100  0.824045  280.234939
# 4281           Guatemala  2009   0.526043  -0.119255  0.645298  122.670213
# 10918              Tonga  1988  -1.881872   0.533522  2.415394  128.350613
# 1653            Cameroon  1988  -7.823632  -7.999074  0.175442    2.242465
# 2081               China  1987  11.719867  12.740519  1.020652    8.708736
#
# [1113 rows x 6 columns]

# %%
#Predicted Value Plot

fig, ax = plt.subplots()
plot_range = [results_df["y_real"].min(), results_df["y_real"].max()] 
ax.set_title("Model performance")
ax.set_ylabel("Pred value")
ax.set_xlabel("Real value")
ax.scatter(results_df["y_real"], results_df["y_pred"], s=4)
ax.plot(plot_range, plot_range, c="red")
plt.show()

# %%
#Filer data by countries using panda
country_list = df.Country.unique()
country = df.loc[df["Country"] == "United Kingdom"]
country.head()

# Time evolution GDP growth of One Country
year = country["Year"]
gdp = country["GDP growth (annual %)"]

fig, ax = plt.subplots()
ax.set_title("GDP Year Evolution")
ax.set_ylabel("GDP Value")
ax.set_xlabel("Year")
ax.grid()
ax.plot(year, gdp, c="red")
plt.show()
