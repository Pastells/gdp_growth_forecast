# %%
import sys
sys.path.append("..")

import utils
import utils.config

import pandas as pd
import sqlite3
import numpy as np

import time

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_squared_error


#from utils import mean_absolute_percentage_error
#Create an utils and import the function

# %%
#Load data from the dataset
conn = sqlite3.connect('../db.sqlite3')

indicators = utils.config.INDICATORS
separator = "',\n'"
sql_string = f""" SELECT
                t2.Country,
                t1.Year,
                t3.IndicatorName,
                t1.Value                
                FROM CountryIndicators t1
                LEFT JOIN
                (SELECT ShortName as Country, CountryCode from Countries) t2
                ON t1.CountryCode = t2.CountryCode
                LEFT JOIN
                (SELECT IndicatorCode, IndicatorName from Indicators)t3
                ON t1.IndicatorCode = t3.IndicatorCode
                WHERE t3.IndicatorName in ('{"','".join(indicators)}');"""

df = pd.read_sql(sql_string,conn)
df = df.groupby(["Country","Year","IndicatorName"]).sum().squeeze().unstack()
df = df.reset_index(level=["Country","Year"])
#print(df.shape)

# Rows where our target is not missing
target = utils.config.TARGET
df = df[df[target].notna()]
df = df.dropna(axis='columns',thresh=6000)
df = df.dropna()
df
#print(df.shape)
# Out:
# IndicatorName      Country  Year  GDP growth (annual %)  \
# 0              Afghanistan  2003               8.444163
# 1              Afghanistan  2004               1.055556
# 2              Afghanistan  2005              11.175270
# 3              Afghanistan  2006               5.554138
# 4              Afghanistan  2007              13.740205
# ...                    ...   ...                    ...
# 9052              Zimbabwe  2006              -3.461495
# 9053              Zimbabwe  2007              -3.653327
# 9054              Zimbabwe  2008             -17.668947
# 9055              Zimbabwe  2009               5.984391
# 9056              Zimbabwe  2010              11.375921
#
# IndicatorName  GDP per capita growth (annual %)
# 0                                      3.528245
# 1                                     -3.212379
# 2                                      7.074088
# 3                                      2.269490
# 4                                     10.690162
# ...                                         ...
# 9052                                  -4.516923
# 9053                                  -4.883986
# 9054                                 -18.874825
# 9055                                   4.242302
# 9056                                   9.360237
#
# [9054 rows x 4 columns]

# %%
#Test of GNI Loading
#GNI = ["Cost of business start-up procedures (% of GNI per capita)",
#    "GNI (constant 2005 US$)",
#    "GNI (constant LCU)"]

#test = df
#gni_columns = df.columns.tolist()
#gni_columns.remove(target)
#gni_columns.remove("Country")
#gni_columns.remove("Year")
#for i in GNI:
#    gni_columns.remove(i)
#test = test.drop(columns=gni_columns)
#test

# %%
country_list = df.Country.unique() #Array with all column names
country = df.loc[df["Country"] == "United Kingdom"]
country.head()
# Out:
# IndicatorName         Country  Year  GDP growth (annual %)  \
# 8522           United Kingdom  1961               2.573570
# 8523           United Kingdom  1962               1.327993
# 8524           United Kingdom  1963               3.956241
# 8525           United Kingdom  1964               5.038282
# 8526           United Kingdom  1965               2.788977
#
# IndicatorName  GDP per capita growth (annual %)
# 8522                                   1.796497
# 8523                                   0.471700
# 8524                                   3.181171
# 8525                                   4.357479
# 8526                                   2.130707

# %%
#Data treatment for one country

X = [] #Indicators (Train)
y = [] #GDP per capita growth (Test)

year_list = (country["Year"].values.tolist())
y = (country[target].values.tolist())
X = country[indicators].to_numpy()

#Arrays lenght
print("Dp lenght (Year list) = ",len(country))

# Hem de modificar els arrays per tal de tenir les dades del gpd de l'any seguent
y.pop(0)

#Last item on X to do the predict
predict_data = X[-1] 
print(f"Y_predict data Shape: {predict_data.shape}")
X = np.delete(X,-1,0)

#To plot the data we need to convert the data in to pandas
y_pandas = pd.Series(y)
X_pandas = pd.DataFrame(X)
print(f"X shape: {X_pandas.shape}")
print(f"y shape: {y_pandas.shape}")
# Out:
# Dp lenght (Year list) =  50
# Y_predict data Shape: (2,)
# X shape: (49, 2)
# y shape: (49,)

# %%
dataset = country
#dataset = df

#X = dataset[features]
#X = dataset.drop(columns=target)
#y = dataset[target]

X_train, X_test, y_train, y_test = train_test_split(X_panda, y_panda, test_size=0.3, random_state=1)

#X_train = X_train.drop(columns=["Country","Year"])
#X_test2 = X_test
#X_test = X_test.drop(columns=["Country","Year"])

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (34, 2)
# X_test shape: (15, 2)
# y_train shape: (34,)
# y_test shape: (15,)

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
linear_y_pred = linear_model.predict(X_test)

results_df = pd.DataFrame(X_test)
#results_df = X_test.copy
#results_df = X_test2

year_list = pd.Series(year_list)
results_df["year"] = year_list
results_df = results_df.sort_values("year")
results_df["y_real"] = y_test
results_df["y_pred"] = linear_y_pred
results_df["err"] = np.absolute(results_df["y_real"] - results_df["y_pred"])
results_df["%_err"] = ((results_df["err"]) /(np.absolute (results_df["y_real"]))* 100)

print(f"RMSE: {mean_squared_error(y_test, linear_y_pred)**0.5}")
print(f"R^2: {r2_score(y_test, linear_y_pred)}")
results_df
# Out:
# RMSE: 1.42617676084987
# R^2: 0.2611249703863787
#            0         1  year    y_real    y_pred       err       %_err
# 2   3.956241  3.181171  1963  5.038282  3.818829  1.219453   24.203750
# 3   5.038282  4.357479  1964  2.788977  3.404535  0.615558   22.071096
# 19 -2.169389 -2.286243  1980 -0.847286  2.892829  3.740116  441.422823
# 21  2.075532  2.112126  1982  4.202240 -0.392650  4.594890  109.343830
# 27  5.934067  5.699087  1988  2.517933  2.477459  0.040474    1.607426
# 29  0.537080  0.236992  1990 -1.236319  2.976722  4.213041  340.773002
# 30 -1.236319 -1.541272  1991  0.446953  2.598452  2.151499  481.369789
# 31  0.446953  0.175681  1992  2.645597  1.800873  0.844723   31.929409
# 34  4.919510  4.642315  1995  2.667813  2.038750  0.629063   23.579725
# 35  2.667813  2.406726  1996  3.098961  1.157062  1.941899   62.662907
# 38  3.112744  2.769533  1999  3.798845  1.802036  1.996809   52.563577
# 39  3.798845  3.428632  2000  2.758035  2.677423  0.080613    2.922835
# 42  3.336665  2.856605  2003  2.488458  2.746993  0.258535   10.389348
# 45  2.661823  1.909975  2006  2.586037  2.613065  0.027028    1.045158
# 48 -4.191945 -4.913894  2009  1.540177  1.040603  0.499574   32.436139

# %%
predict_data = predict_data.reshape(1,-1) #Respahe to predict
linear_y_pred = linear_model.predict(predict_data)
year_pred = (year_list[len(year_list)-1]+1)
print("GDP Growth Prediction: ",year_pred,linear_y_pred)
# Out:
# GDP Growth Prediction:  2011 [1.5873338]

# %%
#Predicted Value Plot

fig, ax = plt.subplots()
plot_range = [results_df["y_real"].min(), results_df["y_real"].max()] 
ax.set_title("Model performance")
ax.set_ylabel("Pred value")
ax.set_xlabel("Real value")
ax.scatter(results_df["y_real"], results_df["y_pred"], s=4)
ax.plot(plot_range, plot_range, c="red")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7d5448739fbb> in <module>
#       2
#       3 fig, ax = plt.subplots()
# ----> 4 plot_range = [results_df["y_real"].min(), results_df["y_real"].max()]
#       5 ax.set_title("Model performance")
#       6 ax.set_ylabel("Pred value")
#
# NameError: name 'results_df' is not defined

# %%
#Gradient Boosting

gbm_hyperparams = {
    'n_estimators': 100,
    'max_depth': 10,
    'learning_rate': 0.1,
    'loss': 'ls'
}
gbm_model = GradientBoostingRegressor(**gbm_hyperparams)

t0 = time.time()
gbm_model.fit(X_train, y_train)
print(f"Elapsed time training: {time.time() - t0} seconds")
t0 = time.time()
gbm_y_pred = gbm_model.predict(X_test)
print(f"Elapsed time predicting: {time.time() - t0} seconds")

results_df = X_test2
results_df = results_df.drop(columns=features)
results_df["y_real"] = y_test
results_df["y_pred"] = gbm_y_pred
results_df["err"] = np.absolute(results_df["y_real"] - results_df["y_pred"])
results_df["%_err"] = ((results_df["err"]) /(np.absolute (results_df["y_real"]))* 100)

print(f"RMSE: {mean_squared_error(y_test, gbm_y_pred)**0.5}")
print(f"R^2: {r2_score(y_test, gbm_y_pred)}")

results_df
# Out:
# Elapsed time training: 0.042748212814331055 seconds
# Elapsed time predicting: 0.002086162567138672 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a886ebd44f3e> in <module>
#      16 print(f"Elapsed time predicting: {time.time() - t0} seconds")
#      17
# ---> 18 results_df = X_test2
#      19 results_df = results_df.drop(columns=features)
#      20 results_df["y_real"] = y_test
#
# NameError: name 'X_test2' is not defined

# %%
#Filer data by countries using panda
country_list = df.Country.unique()
country = df.loc[df["Country"] == "United Kingdom"]
country.head()

# Time evolution GDP growth of One Country
year = country["Year"]
gdp = country["GDP growth (annual %)"]

fig, ax = plt.subplots()
ax.set_title("GDP Year Evolution")
ax.set_ylabel("GDP Value")
ax.set_xlabel("Year")
ax.plot(year, gdp, c="red")
plt.show()

# %%
#Shap Functions

#import shap
#shap.initjs()
#explainer = shap.TreeExplainer(gbm_model)

# %%
#%%time
#shap_values = explainer.shap_values(X_test)

# %%
#shap.summary_plot(shap_values, X_test)

# %%
#shap.force_plot(explainer.expected_value, shap_values, X_test)

# %%
#shap.summary_plot(shap_values, X_test, plot_type="bar")
